# %% [markdown]
# #6 Online Class Project 6: Bulk File Re-namer Python Project

# %%
"""
Bulk Rename Magic 💫

A Python script to perform bulk renaming of files in a specified directory.
Allows you to add prefixes, suffixes, or replace substrings in filenames.

"""

import os
from typing import List


def bulk_rename(directory: str, operation: str, modifier: str = "", old_substr: str = "", new_subst: str = "") -> None:
    """
    Renames files in the given directory based on the specified operation.

    Parameters:
        directory (str): The path to the directory containing files.
        operation (str): The renaming operation to perform. Must be one of "prefix", "suffix", or "replace".
        modifier (str, optional): The string to use for prefix or suffix operations.
        old_substr (str, optional): The substring to search for (in replace operation).
        new_subst (str, optional): The replacement substring (in replace operation).
    """
    # Get a list of all files in the directory
    files: List[str] = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

    if not files:
        print("\033[1;31mError: No files found in the specified directory! 😢\033[0m")
        return

    print(f"\033[92mFound {len(files)} file(s) to rename in '{directory}'. Let's rock! 🎸\033[0m")

    # Iterate over each file and compute its new name based on the operation
    for file_name in files:
        old_file_path: str = os.path.join(directory, file_name)
        name, ext = os.path.splitext(file_name)
        new_name: str = file_name  # default new name (unchanged)

        if operation == "prefix":
            new_name = modifier + file_name
        elif operation == "suffix":
            new_name = name + modifier + ext
        elif operation == "replace":
            new_name = file_name.replace(old_substr, new_subst)

        new_file_path: str = os.path.join(directory, new_name)

        try:
            os.rename(old_file_path, new_file_path)
            print(f"\033[92mSuccess: Renamed '{file_name}' to '{new_name}' ✅\033[0m")
        except Exception as e:
            print(f"\033[1;31mError renaming '{file_name}': {e} ❌\033[0m")


def main() -> None:
    """
    Main function to run the Bulk Rename Magic project.
    Prompts the user for the directory and type of renaming operation.
    """
    # Welcome message in green
    print("\033[92mWelcome to Bulk Rename Magic! 🤖 Let's rename some files in bulk! 💫\033[0m")

    # Get the directory path from the user with a colored input prompt (cyan)
    directory: str = input("\033[96mEnter the directory path containing files to rename: \033[0m").strip()

    # Check if the provided directory exists
    if not os.path.isdir(directory):
        print("\033[1;31mError: The specified directory does not exist! 🚫\033[0m")
        return

    # Display renaming options to the user
    print("\033[96mChoose a renaming option:\033[0m")
    print("\033[96m1: Add prefix\033[0m")
    print("\033[96m2: Add suffix\033[0m")
    print("\033[96m3: Replace substring\033[0m")

    # Read and validate the renaming option
    try:
        option: int = int(input("\033[96mEnter your option (1, 2, or 3): \033[0m").strip())
    except ValueError:
        print("\033[1;31mError: Invalid input! Please enter a number (1, 2, or 3). 🚫\033[0m")
        return

    # Initialize variables for renaming operation
    operation: str = ""
    modifier: str = ""
    old_substr: str = ""
    new_subst: str = ""

    # Based on the option, get the additional modification parameters
    if option == 1:
        operation = "prefix"
        modifier = input("\033[96mEnter the prefix to add: \033[0m")
    elif option == 2:
        operation = "suffix"
        modifier = input("\033[96mEnter the suffix to add (before file extension): \033[0m")
    elif option == 3:
        operation = "replace"
        old_substr = input("\033[96mEnter the substring to replace: \033[0m")
        new_subst = input("\033[96mEnter the new substring: \033[0m")
    else:
        print("\033[1;31mError: Invalid option selected! 🚫\033[0m")
        return

    # Call the bulk_rename function to perform the renaming process
    bulk_rename(directory, operation, modifier, old_substr, new_subst)

    print("\033[92mBulk renaming process completed! 🚀\033[0m")


# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
    main()
# Out:
# Welcome to Bulk Rename Magic! 🤖 Let's rename some files in bulk! 💫
# Enter the directory path containing files to rename: /content/sample_data
# Choose a renaming option:
# 1: Add prefix
# 2: Add suffix
# 3: Replace substring
# Enter your option (1, 2, or 3): 2
# Enter the suffix to add (before file extension): _google
# Found 6 file(s) to rename in '/content/sample_data'. Let's rock! 🎸
# Success: Renamed 'README.md' to 'README_google.md' ✅
# Success: Renamed 'anscombe.json' to 'anscombe_google.json' ✅
# Success: Renamed 'california_housing_train.csv' to 'california_housing_train_google.csv' ✅
# Success: Renamed 'mnist_train_small.csv' to 'mnist_train_small_google.csv' ✅
# Success: Renamed 'mnist_test.csv' to 'mnist_test_google.csv' ✅
# Success: Renamed 'california_housing_test.csv' to 'california_housing_test_google.csv' ✅
# Bulk renaming process completed! 🚀

# %% [markdown]
# ##Same thing but in object oriented programming

# %%
import os
from typing import List


class BulkRenameMagic:
    def __init__(self, directory: str):
        self.directory = directory
        self.files = self.get_files()

    def get_files(self) -> List[str]:
        """Retrieves all files in the specified directory."""
        if not os.path.isdir(self.directory):
            print("\033[1;31mError: The specified directory does not exist! 🚫\033[0m")
            return []
        return [f for f in os.listdir(self.directory) if os.path.isfile(os.path.join(self.directory, f))]

    def rename_files(self, operation: str, modifier: str = "", old_substr: str = "", new_subst: str = "") -> None:
        """Renames files based on the selected operation."""
        if not self.files:
            print("\033[1;31mError: No files found in the specified directory! 😢\033[0m")
            return

        print(f"\033[92mFound {len(self.files)} file(s) to rename in '{self.directory}'. Let's rock! 🎸\033[0m")

        for file_name in self.files:
            old_file_path = os.path.join(self.directory, file_name)
            name, ext = os.path.splitext(file_name)
            new_name = file_name

            if operation == "prefix":
                new_name = modifier + file_name
            elif operation == "suffix":
                new_name = name + modifier + ext
            elif operation == "replace":
                new_name = file_name.replace(old_substr, new_subst)

            new_file_path = os.path.join(self.directory, new_name)

            try:
                os.rename(old_file_path, new_file_path)
                print(f"\033[92mSuccess: Renamed '{file_name}' to '{new_name}' ✅\033[0m")
            except Exception as e:
                print(f"\033[1;31mError renaming '{file_name}': {e} ❌\033[0m")

    @staticmethod
    def get_user_input() -> "BulkRenameMagic":
        """Handles user input for directory selection and returns an instance of BulkRenameMagic."""
        print("\033[92mWelcome to Bulk Rename Magic! 🤖 Let's rename some files in bulk! 💫\033[0m")
        directory = input("\033[96mEnter the directory path containing files to rename: \033[0m").strip()
        return BulkRenameMagic(directory)

    def prompt_user_and_rename(self):
        """Handles user input for renaming operations and executes the renaming process."""
        if not self.files:
            return

        print("\033[96mChoose a renaming option:\033[0m")
        print("\033[96m1: Add prefix\033[0m")
        print("\033[96m2: Add suffix\033[0m")
        print("\033[96m3: Replace substring\033[0m")

        try:
            option = int(input("\033[96mEnter your option (1, 2, or 3): \033[0m").strip())
        except ValueError:
            print("\033[1;31mError: Invalid input! Please enter a number (1, 2, or 3). 🚫\033[0m")
            return

        operation = ""
        modifier = ""
        old_substr = ""
        new_subst = ""

        if option == 1:
            operation = "prefix"
            modifier = input("\033[96mEnter the prefix to add: \033[0m").strip()
        elif option == 2:
            operation = "suffix"
            modifier = input("\033[96mEnter the suffix to add (before file extension): \033[0m").strip()
        elif option == 3:
            operation = "replace"
            old_substr = input("\033[96mEnter the substring to replace: \033[0m").strip()
            new_subst = input("\033[96mEnter the new substring: \033[0m").strip()
        else:
            print("\033[1;31mError: Invalid option selected! 🚫\033[0m")
            return

        self.rename_files(operation, modifier, old_substr, new_subst)
        print("\033[92mBulk renaming process completed! 🚀\033[0m")


def main():
    renamer = BulkRenameMagic.get_user_input()
    renamer.prompt_user_and_rename()


if __name__ == "__main__":
    main()
# Out:
# Welcome to Bulk Rename Magic! 🤖 Let's rename some files in bulk! 💫
# Enter the directory path containing files to rename: /bin
# Choose a renaming option:
# 1: Add prefix
# 2: Add suffix
# 3: Replace substring
# Enter your option (1, 2, or 3): 1
# Enter the prefix to add: __~
# Found 963 file(s) to rename in '/bin'. Let's rock! 🎸
# Success: Renamed 'fgrep' to '__~fgrep' ✅
# Success: Renamed 'lscpu' to '__~lscpu' ✅
# Success: Renamed 'tee' to '__~tee' ✅
# Success: Renamed 'apt-config' to '__~apt-config' ✅
# Success: Renamed 'diff' to '__~diff' ✅
# Success: Renamed 'du' to '__~du' ✅
# Success: Renamed 'cmp' to '__~cmp' ✅
# Success: Renamed 'lastb' to '__~lastb' ✅
# Success: Renamed 'setpriv' to '__~setpriv' ✅
# Success: Renamed 'dpkg-divert' to '__~dpkg-divert' ✅
# Success: Renamed 'dpkg-maintscript-helper' to '__~dpkg-maintscript-helper' ✅
# Success: Renamed 'dpkg-query' to '__~dpkg-query' ✅
# Success: Renamed 'watch' to '__~watch' ✅
# Success: Renamed 'ps' to '__~ps' ✅
# Success: Renamed 'dd' to '__~dd' ✅
# Success: Renamed 'base32' to '__~base32' ✅
# Success: Renamed 'clear_console' to '__~clear_console' ✅
# Success: Renamed 'x86_64' to '__~x86_64' ✅
# Success: Renamed 'pmap' to '__~pmap' ✅
# Success: Renamed 'ionice' to '__~ionice' ✅
# Success: Renamed 'unlink' to '__~unlink' ✅
# Success: Renamed 'savelog' to '__~savelog' ✅
# Success: Renamed 'fold' to '__~fold' ✅
# Success: Renamed 'pr' to '__~pr' ✅
# Success: Renamed 'cut' to '__~cut' ✅
# Success: Renamed 'mktemp' to '__~mktemp' ✅
# Success: Renamed 'chcon' to '__~chcon' ✅
# Success: Renamed 'sha512sum' to '__~sha512sum' ✅
# Success: Renamed 'reset' to '__~reset' ✅
# Success: Renamed 'who' to '__~who' ✅
# Success: Renamed 'resizepart' to '__~resizepart' ✅
# Success: Renamed 'mesg' to '__~mesg' ✅
# Success: Renamed 'addpart' to '__~addpart' ✅
# Success: Renamed 'zcmp' to '__~zcmp' ✅
# Success: Renamed 'newgrp' to '__~newgrp' ✅
# Success: Renamed 'stdbuf' to '__~stdbuf' ✅
# Success: Renamed 'localedef' to '__~localedef' ✅
# Success: Renamed 'base64' to '__~base64' ✅
# Success: Renamed 'uniq' to '__~uniq' ✅
# Success: Renamed 'vmstat' to '__~vmstat' ✅
# Success: Renamed 'toe' to '__~toe' ✅
# Success: Renamed 'shuf' to '__~shuf' ✅
# Success: Renamed 'zmore' to '__~zmore' ✅
# Success: Renamed 'printenv' to '__~printenv' ✅
# Success: Renamed 'nsenter' to '__~nsenter' ✅
# Success: Renamed 'rm' to '__~rm' ✅
# Success: Renamed 'i386' to '__~i386' ✅
# Success: Renamed 'renice' to '__~renice' ✅
# Success: Renamed 'comm' to '__~comm' ✅
# Success: Renamed 'tsort' to '__~tsort' ✅
# Success: Renamed 'test' to '__~test' ✅
# Success: Renamed 'fmt' to '__~fmt' ✅
# Success: Renamed 'taskset' to '__~taskset' ✅
# Success: Renamed 'gunzip' to '__~gunzip' ✅
# Success: Renamed 'passwd' to '__~passwd' ✅
# Success: Renamed 'bashbug' to '__~bashbug' ✅
# Success: Renamed 'utmpdump' to '__~utmpdump' ✅
# Success: Renamed 'gzip' to '__~gzip' ✅
# Success: Renamed 'sh' to '__~sh' ✅
# Success: Renamed 'chage' to '__~chage' ✅
# Success: Renamed 'tic' to '__~tic' ✅
# Success: Renamed 'fincore' to '__~fincore' ✅
# Success: Renamed 'expiry' to '__~expiry' ✅
# Success: Renamed 'dpkg-statoverride' to '__~dpkg-statoverride' ✅
# Success: Renamed 'debconf-show' to '__~debconf-show' ✅
# Success: Renamed 'deb-systemd-helper' to '__~deb-systemd-helper' ✅
# Success: Renamed 'pidwait' to '__~pidwait' ✅
# Success: Renamed 'gzexe' to '__~gzexe' ✅
# Success: Renamed 'sensible-pager' to '__~sensible-pager' ✅
# Success: Renamed 'ipcs' to '__~ipcs' ✅
# Success: Renamed 'vdir' to '__~vdir' ✅
# Success: Renamed 'hardlink' to '__~hardlink' ✅
# Success: Renamed 'apt-key' to '__~apt-key' ✅
# Success: Renamed 'nisdomainname' to '__~nisdomainname' ✅
# Success: Renamed 'split' to '__~split' ✅
# Success: Renamed 'pwd' to '__~pwd' ✅
# Success: Renamed 'nproc' to '__~nproc' ✅
# Success: Renamed 'debconf-apt-progress' to '__~debconf-apt-progress' ✅
# Success: Renamed 'arch' to '__~arch' ✅
# Success: Renamed 'ptx' to '__~ptx' ✅
# Success: Renamed 'dnsdomainname' to '__~dnsdomainname' ✅
# Success: Renamed 'pager' to '__~pager' ✅
# Success: Renamed 'nohup' to '__~nohup' ✅
# Success: Renamed 'perl5.34.0' to '__~perl5.34.0' ✅
# Success: Renamed 'znew' to '__~znew' ✅
# Success: Renamed 'sha384sum' to '__~sha384sum' ✅
# Success: Renamed 'install' to '__~install' ✅
# Success: Renamed 'basenc' to '__~basenc' ✅
# Success: Renamed 'apt-mark' to '__~apt-mark' ✅
# Success: Renamed 'tempfile' to '__~tempfile' ✅
# Success: Renamed 'users' to '__~users' ✅
# Success: Renamed 'uncompress' to '__~uncompress' ✅
# Success: Renamed 'dash' to '__~dash' ✅
# Success: Renamed 'faillog' to '__~faillog' ✅
# Success: Renamed 'paste' to '__~paste' ✅
# Success: Renamed 'sum' to '__~sum' ✅
# Success: Renamed 'which' to '__~which' ✅
# Success: Renamed 'dpkg-deb' to '__~dpkg-deb' ✅
# Success: Renamed 'gpgv' to '__~gpgv' ✅
# Success: Renamed 'mawk' to '__~mawk' ✅
# Success: Renamed 'debconf-communicate' to '__~debconf-communicate' ✅
# Success: Renamed 'whoami' to '__~whoami' ✅
# Success: Renamed 'bash' to '__~bash' ✅
# Success: Renamed 'dmesg' to '__~dmesg' ✅
# Success: Renamed 'df' to '__~df' ✅
# Success: Renamed 'debconf-escape' to '__~debconf-escape' ✅
# Success: Renamed 'pldd' to '__~pldd' ✅
# Success: Renamed 'prlimit' to '__~prlimit' ✅
# Success: Renamed 'md5sum' to '__~md5sum' ✅
# Success: Renamed 'zdiff' to '__~zdiff' ✅
# Success: Renamed 'logger' to '__~logger' ✅
# Success: Renamed 'csplit' to '__~csplit' ✅
# Success: Renamed 'pgrep' to '__~pgrep' ✅
# Success: Renamed 'lsmem' to '__~lsmem' ✅
# Success: Renamed 'tset' to '__~tset' ✅
# Success: Renamed 'dpkg-trigger' to '__~dpkg-trigger' ✅
# Success: Renamed '[' to '__~[' ✅
# Success: Renamed 'diff3' to '__~diff3' ✅
# Success: Renamed 'scriptlive' to '__~scriptlive' ✅
# Success: Renamed 'mknod' to '__~mknod' ✅
# Success: Renamed 'getconf' to '__~getconf' ✅
# Success: Renamed 'su' to '__~su' ✅
# Success: Renamed 'head' to '__~head' ✅
# Success: Renamed 'locale-check' to '__~locale-check' ✅
# Success: Renamed 'md5sum.textutils' to '__~md5sum.textutils' ✅
# Success: Renamed 'update-alternatives' to '__~update-alternatives' ✅
# Success: Renamed 'locale' to '__~locale' ✅
# Success: Renamed 'rmdir' to '__~rmdir' ✅
# Success: Renamed 'pidof' to '__~pidof' ✅
# Success: Renamed 'mkdir' to '__~mkdir' ✅
# Success: Renamed 'man' to '__~man' ✅
# Success: Renamed 'select-editor' to '__~select-editor' ✅
# Success: Renamed 'stty' to '__~stty' ✅
# Success: Renamed 'nawk' to '__~nawk' ✅
# Success: Renamed 'rev' to '__~rev' ✅
# Success: Renamed 'last' to '__~last' ✅
# Success: Renamed 'flock' to '__~flock' ✅
# Success: Renamed 'printf' to '__~printf' ✅
# Success: Renamed 'tabs' to '__~tabs' ✅
# Success: Renamed 'dpkg' to '__~dpkg' ✅
# Success: Renamed 'ypdomainname' to '__~ypdomainname' ✅
# Success: Renamed 'date' to '__~date' ✅
# Success: Renamed 'join' to '__~join' ✅
# Success: Renamed 'mv' to '__~mv' ✅
# Success: Renamed 'hostid' to '__~hostid' ✅
# Success: Renamed 'expr' to '__~expr' ✅
# Success: Renamed 'scriptreplay' to '__~scriptreplay' ✅
# Success: Renamed 'which.debianutils' to '__~which.debianutils' ✅
# Success: Renamed 'runcon' to '__~runcon' ✅
# Success: Renamed 'find' to '__~find' ✅
# Success: Renamed 'chrt' to '__~chrt' ✅
# Success: Renamed 'pkill' to '__~pkill' ✅
# Success: Renamed 'setterm' to '__~setterm' ✅
# Success: Renamed 'fallocate' to '__~fallocate' ✅
# Success: Renamed 'getopt' to '__~getopt' ✅
# Success: Renamed 'w' to '__~w' ✅
# Success: Renamed 'run-parts' to '__~run-parts' ✅
# Success: Renamed 'sensible-browser' to '__~sensible-browser' ✅
# Success: Renamed 'rgrep' to '__~rgrep' ✅
# Success: Renamed 'rbash' to '__~rbash' ✅
# Success: Renamed 'zless' to '__~zless' ✅
# Success: Renamed 'partx' to '__~partx' ✅
# Success: Renamed 'id' to '__~id' ✅
# Success: Renamed 'zgrep' to '__~zgrep' ✅
# Success: Renamed 'readlink' to '__~readlink' ✅
# Success: Renamed 'ln' to '__~ln' ✅
# Success: Renamed 'tac' to '__~tac' ✅
# Success: Renamed 'dir' to '__~dir' ✅
# Success: Renamed 'tload' to '__~tload' ✅
# Success: Renamed 'logname' to '__~logname' ✅
# Success: Renamed 'chsh' to '__~chsh' ✅
# Success: Renamed 'getent' to '__~getent' ✅
# Success: Renamed 'pinky' to '__~pinky' ✅
# Success: Renamed 'nice' to '__~nice' ✅
# Success: Renamed 'umount' to '__~umount' ✅
# Success: Renamed 'cksum' to '__~cksum' ✅
# Success: Renamed 'pwdx' to '__~pwdx' ✅
# Success: Renamed 'zforce' to '__~zforce' ✅
# Success: Renamed 'unshare' to '__~unshare' ✅
# Success: Renamed 'debconf-copydb' to '__~debconf-copydb' ✅
# Success: Renamed 'sort' to '__~sort' ✅
# Success: Renamed 'chgrp' to '__~chgrp' ✅
# Success: Renamed 'ipcmk' to '__~ipcmk' ✅
# Success: Renamed 'env' to '__~env' ✅
# Success: Renamed 'sha224sum' to '__~sha224sum' ✅
# Success: Renamed 'truncate' to '__~truncate' ✅
# Success: Renamed 'perl' to '__~perl' ✅
# Success: Renamed 'setarch' to '__~setarch' ✅
# Success: Renamed 'lslocks' to '__~lslocks' ✅
# Success: Renamed 'mcookie' to '__~mcookie' ✅
# Success: Renamed 'yes' to '__~yes' ✅
# Success: Renamed 'od' to '__~od' ✅
# Success: Renamed 'tput' to '__~tput' ✅
# Success: Renamed 'egrep' to '__~egrep' ✅
# Success: Renamed 'sha256sum' to '__~sha256sum' ✅
# Success: Renamed 'nl' to '__~nl' ✅
# Success: Renamed 'cat' to '__~cat' ✅
# Success: Renamed 'false' to '__~false' ✅
# Success: Renamed 'dirname' to '__~dirname' ✅
# Success: Renamed 'dpkg-realpath' to '__~dpkg-realpath' ✅
# Success: Renamed 'expand' to '__~expand' ✅
# Success: Renamed 'skill' to '__~skill' ✅
# Success: Renamed 'xargs' to '__~xargs' ✅
# Success: Renamed 'hostname' to '__~hostname' ✅
# Success: Renamed 'lsipc' to '__~lsipc' ✅
# Success: Renamed 'chmod' to '__~chmod' ✅
# Success: Renamed 'free' to '__~free' ✅
# Success: Renamed 'whereis' to '__~whereis' ✅
# Success: Renamed 'snice' to '__~snice' ✅
# Success: Renamed 'b2sum' to '__~b2sum' ✅
# Success: Renamed 'ls' to '__~ls' ✅
# Success: Renamed 'sleep' to '__~sleep' ✅
# Success: Renamed 'unexpand' to '__~unexpand' ✅
# Success: Renamed 'lsns' to '__~lsns' ✅
# Success: Renamed 'lsattr' to '__~lsattr' ✅
# Success: Renamed 'sha1sum' to '__~sha1sum' ✅
# Success: Renamed 'apt-get' to '__~apt-get' ✅
# Success: Renamed 'numfmt' to '__~numfmt' ✅
# Success: Renamed 'apt-cdrom' to '__~apt-cdrom' ✅
# Success: Renamed 'tty' to '__~tty' ✅
# Success: Renamed 'domainname' to '__~domainname' ✅
# Success: Renamed 'kill' to '__~kill' ✅
# Success: Renamed 'groups' to '__~groups' ✅
# Success: Renamed 'uptime' to '__~uptime' ✅
# Success: Renamed 'mountpoint' to '__~mountpoint' ✅
# Success: Renamed 'infocmp' to '__~infocmp' ✅
# Success: Renamed 'sg' to '__~sg' ✅
# Success: Renamed 'linux32' to '__~linux32' ✅
# Success: Renamed 'link' to '__~link' ✅
# Success: Renamed 'dircolors' to '__~dircolors' ✅
# Success: Renamed 'tr' to '__~tr' ✅
# Success: Renamed 'ldd' to '__~ldd' ✅
# Success: Renamed 'shred' to '__~shred' ✅
# Success: Renamed 'stat' to '__~stat' ✅
# Success: Renamed 'setsid' to '__~setsid' ✅
# Success: Renamed 'wdctl' to '__~wdctl' ✅
# Success: Renamed 'lastlog' to '__~lastlog' ✅
# Success: Renamed 'echo' to '__~echo' ✅
# Success: Renamed 'zfgrep' to '__~zfgrep' ✅
# Success: Renamed 'debconf-set-selections' to '__~debconf-set-selections' ✅
# Success: Renamed 'infotocap' to '__~infotocap' ✅
# Success: Renamed 'findmnt' to '__~findmnt' ✅
# Success: Renamed 'choom' to '__~choom' ✅
# Success: Renamed 'more' to '__~more' ✅
# Success: Renamed 'lslogins' to '__~lslogins' ✅
# Success: Renamed 'wc' to '__~wc' ✅
# Success: Renamed 'mkfifo' to '__~mkfifo' ✅
# Success: Renamed 'deb-systemd-invoke' to '__~deb-systemd-invoke' ✅
# Success: Renamed 'ischroot' to '__~ischroot' ✅
# Success: Renamed 'factor' to '__~factor' ✅
# Success: Renamed 'uname' to '__~uname' ✅
# Success: Renamed 'chown' to '__~chown' ✅
# Success: Renamed 'login' to '__~login' ✅
# Success: Renamed 'chfn' to '__~chfn' ✅
# Success: Renamed 'sensible-editor' to '__~sensible-editor' ✅
# Success: Renamed 'grep' to '__~grep' ✅
# Success: Renamed 'chattr' to '__~chattr' ✅
# Success: Renamed 'script' to '__~script' ✅
# Success: Renamed 'timeout' to '__~timeout' ✅
# Success: Renamed 'namei' to '__~namei' ✅
# Success: Renamed 'clear' to '__~clear' ✅
# Success: Renamed 'top' to '__~top' ✅
# Success: Renamed 'captoinfo' to '__~captoinfo' ✅
# Success: Renamed 'zcat' to '__~zcat' ✅
# Success: Renamed 'sync' to '__~sync' ✅
# Success: Renamed 'sdiff' to '__~sdiff' ✅
# Success: Renamed 'cp' to '__~cp' ✅
# Success: Renamed 'lsblk' to '__~lsblk' ✅
# Success: Renamed 'slabtop' to '__~slabtop' ✅
# Success: Renamed 'seq' to '__~seq' ✅
# Success: Renamed 'touch' to '__~touch' ✅
# Success: Renamed 'true' to '__~true' ✅
# Success: Renamed 'dpkg-split' to '__~dpkg-split' ✅
# Success: Renamed 'awk' to '__~awk' ✅
# Success: Renamed 'debconf' to '__~debconf' ✅
# Success: Renamed 'delpart' to '__~delpart' ✅
# Success: Renamed 'apt-cache' to '__~apt-cache' ✅
# Success: Renamed 'linux64' to '__~linux64' ✅
# Success: Renamed 'realpath' to '__~realpath' ✅
# Success: Renamed 'tail' to '__~tail' ✅
# Success: Renamed 'zegrep' to '__~zegrep' ✅
# Success: Renamed 'iconv' to '__~iconv' ✅
# Success: Renamed 'apt' to '__~apt' ✅
# Success: Renamed 'tar' to '__~tar' ✅
# Success: Renamed 'uclampset' to '__~uclampset' ✅
# Success: Renamed 'gpasswd' to '__~gpasswd' ✅
# Success: Renamed 'pathchk' to '__~pathchk' ✅
# Success: Renamed 'sed' to '__~sed' ✅
# Success: Renamed 'wall' to '__~wall' ✅
# Success: Renamed 'zdump' to '__~zdump' ✅
# Success: Renamed 'mount' to '__~mount' ✅
# Success: Renamed 'basename' to '__~basename' ✅
# Success: Renamed 'tzselect' to '__~tzselect' ✅
# Success: Renamed 'ipcrm' to '__~ipcrm' ✅
# Success: Renamed 'systemctl' to '__~systemctl' ✅
# Success: Renamed 'unzip' to '__~unzip' ✅
# Success: Renamed 'pkaction' to '__~pkaction' ✅
# Success: Renamed 'file' to '__~file' ✅
# Success: Renamed 'ctest' to '__~ctest' ✅
# Success: Renamed 'gxl2dot' to '__~gxl2dot' ✅
# Success: Renamed 'nnsd' to '__~nnsd' ✅
# Success: Renamed 'ssh-agent' to '__~ssh-agent' ✅
# Success: Renamed 'sudoreplay' to '__~sudoreplay' ✅
# Success: Renamed 'ncursesw5-config' to '__~ncursesw5-config' ✅
# Success: Renamed 'systemd-run' to '__~systemd-run' ✅
# Success: Renamed 'aclocal' to '__~aclocal' ✅
# Success: Renamed 'git' to '__~git' ✅
# Success: Renamed 'pcre2-config' to '__~pcre2-config' ✅
# Success: Renamed 'parallel' to '__~parallel' ✅
# Success: Renamed 'fio2gnuplot' to '__~fio2gnuplot' ✅
# Success: Renamed 'helpztags' to '__~helpztags' ✅
# Success: Renamed 'python3.10' to '__~python3.10' ✅
# Success: Renamed 'zipgrep' to '__~zipgrep' ✅
# Success: Renamed 'xdg-open' to '__~xdg-open' ✅
# Success: Renamed 'pt' to '__~pt' ✅
# Success: Renamed 'fio-verify-state' to '__~fio-verify-state' ✅
# Success: Renamed 'autoreconf' to '__~autoreconf' ✅
# Success: Renamed 'serialver' to '__~serialver' ✅
# Success: Renamed 'chronic' to '__~chronic' ✅
# Success: Renamed 'fio_generate_plots' to '__~fio_generate_plots' ✅
# Success: Renamed 'systemd-cryptenroll' to '__~systemd-cryptenroll' ✅
# Success: Renamed 'ucfr' to '__~ucfr' ✅
# Success: Renamed 'tmux' to '__~tmux' ✅
# Success: Renamed 'python3' to '__~python3' ✅
# Success: Renamed 'glib-compile-schemas' to '__~glib-compile-schemas' ✅
# Success: Renamed 'oshcxx' to '__~oshcxx' ✅
# Success: Renamed 'systemd-tty-ask-password-agent' to '__~systemd-tty-ask-password-agent' ✅
# Success: Renamed 'apropos' to '__~apropos' ✅
# Success: Renamed 'jinfo' to '__~jinfo' ✅
# Success: Renamed 'pygettext3.11' to '__~pygettext3.11' ✅
# Success: Renamed 'ncurses5-config' to '__~ncurses5-config' ✅
# Success: Renamed 'xdg-mime' to '__~xdg-mime' ✅
# Success: Renamed 'ip' to '__~ip' ✅
# Success: Renamed 'vimdot' to '__~vimdot' ✅
# Success: Renamed 'combine' to '__~combine' ✅
# Success: Renamed 'write.ul' to '__~write.ul' ✅
# Success: Renamed 'tcltk-depends' to '__~tcltk-depends' ✅
# Success: Renamed 'zipnote' to '__~zipnote' ✅
# Success: Renamed 'ifdata' to '__~ifdata' ✅
# Success: Renamed 'gv2gml' to '__~gv2gml' ✅
# Success: Renamed 'oshCC' to '__~oshCC' ✅
# Success: Renamed 'git-receive-pack' to '__~git-receive-pack' ✅
# Success: Renamed 'xdg-settings' to '__~xdg-settings' ✅
# Success: Renamed 'javap' to '__~javap' ✅
# Success: Renamed 'zipsplit' to '__~zipsplit' ✅
# Success: Renamed 'diffimg' to '__~diffimg' ✅
# Success: Renamed 'lnstat' to '__~lnstat' ✅
# Success: Renamed 'print' to '__~print' ✅
# Success: Renamed 'x86_64-linux-gnu-python3.11-config' to '__~x86_64-linux-gnu-python3.11-config' ✅
# Success: Renamed 'vi' to '__~vi' ✅
# Success: Renamed 'quickbook' to '__~quickbook' ✅
# Success: Renamed 'compile_et' to '__~compile_et' ✅
# Success: Renamed 'xdg-email' to '__~xdg-email' ✅
# Success: Renamed 'xxd' to '__~xxd' ✅
# Success: Renamed 'pydoc3' to '__~pydoc3' ✅
# Success: Renamed 'dtplite' to '__~dtplite' ✅
# Success: Renamed 'xdg-screensaver' to '__~xdg-screensaver' ✅
# Success: Renamed 'keyring' to '__~keyring' ✅
# Success: Renamed 'ffmpeg' to '__~ffmpeg' ✅
# Success: Renamed 'Rscript' to '__~Rscript' ✅
# Success: Renamed 'mm2gv' to '__~mm2gv' ✅
# Success: Renamed 'vidir' to '__~vidir' ✅
# Success: Renamed 'mpijavac.pl' to '__~mpijavac.pl' ✅
# Success: Renamed 'gsettings' to '__~gsettings' ✅
# Success: Renamed 'mpirun.openmpi' to '__~mpirun.openmpi' ✅
# Success: Renamed 'rvim' to '__~rvim' ✅
# Success: Renamed 'routef' to '__~routef' ✅
# Success: Renamed 'aclocal-1.16' to '__~aclocal-1.16' ✅
# Success: Renamed 'python3.11' to '__~python3.11' ✅
# Success: Renamed 'tclsh8.6' to '__~tclsh8.6' ✅
# Success: Renamed 'graphml2gv' to '__~graphml2gv' ✅
# Success: Renamed 'scp' to '__~scp' ✅
# Success: Renamed 'gapplication' to '__~gapplication' ✅
# Success: Renamed 'fc-list' to '__~fc-list' ✅
# Success: Renamed 'mpifort' to '__~mpifort' ✅
# Success: Renamed 'opencv_visualisation' to '__~opencv_visualisation' ✅
# Success: Renamed '7za' to '__~7za' ✅
# Success: Renamed 'mpiCC.openmpi' to '__~mpiCC.openmpi' ✅
# Success: Renamed 'inspect' to '__~inspect' ✅
# Success: Renamed 'ssh' to '__~ssh' ✅
# Success: Renamed 'genfio' to '__~genfio' ✅
# Success: Renamed 'gtbl' to '__~gtbl' ✅
# Success: Renamed 'mpiCC' to '__~mpiCC' ✅
# Success: Renamed 'troff' to '__~troff' ✅
# Success: Renamed 'gvmap' to '__~gvmap' ✅
# Success: Renamed 'ss' to '__~ss' ✅
# Success: Renamed 'oshmem_info' to '__~oshmem_info' ✅
# Success: Renamed 'pdb3.11' to '__~pdb3.11' ✅
# Success: Renamed 'hostnamectl' to '__~hostnamectl' ✅
# Success: Renamed 'ortecc' to '__~ortecc' ✅
# Success: Renamed 'tbl' to '__~tbl' ✅
# Success: Renamed 'fio_jsonplus_clat2csv' to '__~fio_jsonplus_clat2csv' ✅
# Success: Renamed 'lsmod' to '__~lsmod' ✅
# Success: Renamed 'oshcc' to '__~oshcc' ✅
# Success: Renamed 'systemd-cat' to '__~systemd-cat' ✅
# Success: Renamed 'busctl' to '__~busctl' ✅
# Success: Renamed 'git-upload-archive' to '__~git-upload-archive' ✅
# Success: Renamed 'clang-14' to '__~clang-14' ✅
# Success: Renamed 'jar' to '__~jar' ✅
# Success: Renamed 'eqn' to '__~eqn' ✅
# Success: Renamed 'curl-config' to '__~curl-config' ✅
# Success: Renamed 'fc-scan' to '__~fc-scan' ✅
# Success: Renamed 'rrsync' to '__~rrsync' ✅
# Success: Renamed 'ompi_info' to '__~ompi_info' ✅
# Success: Renamed 'cpack' to '__~cpack' ✅
# Success: Renamed 'tred' to '__~tred' ✅
# Success: Renamed 'gresource' to '__~gresource' ✅
# Success: Renamed 'look' to '__~look' ✅
# Success: Renamed 'jhsdb' to '__~jhsdb' ✅
# Success: Renamed 'compose' to '__~compose' ✅
# Success: Renamed 'grotty' to '__~grotty' ✅
# Success: Renamed 'dbus-daemon' to '__~dbus-daemon' ✅
# Success: Renamed 'dbus-run-session' to '__~dbus-run-session' ✅
# Success: Renamed 'ucf' to '__~ucf' ✅
# Success: Renamed 'pkcheck' to '__~pkcheck' ✅
# Success: Renamed 'kernel-install' to '__~kernel-install' ✅
# Success: Renamed 'gencat' to '__~gencat' ✅
# Success: Renamed 'browse' to '__~browse' ✅
# Success: Renamed 'see' to '__~see' ✅
# Success: Renamed 'systemd-cgtop' to '__~systemd-cgtop' ✅
# Success: Renamed 'localectl' to '__~localectl' ✅
# Success: Renamed 'gvgen' to '__~gvgen' ✅
# Success: Renamed 'ssh-argv0' to '__~ssh-argv0' ✅
# Success: Renamed 'tclsh' to '__~tclsh' ✅
# Success: Renamed 'journalctl' to '__~journalctl' ✅
# Success: Renamed 'jmap' to '__~jmap' ✅
# Success: Renamed 'R' to '__~R' ✅
# Success: Renamed 'ogdi-config' to '__~ogdi-config' ✅
# Success: Renamed 'orterun' to '__~orterun' ✅
# Success: Renamed 'lessfile' to '__~lessfile' ✅
# Success: Renamed 'pstree.x11' to '__~pstree.x11' ✅
# Success: Renamed 'dbus-send' to '__~dbus-send' ✅
# Success: Renamed 'groff' to '__~groff' ✅
# Success: Renamed 'view' to '__~view' ✅
# Success: Renamed 'krb5-config' to '__~krb5-config' ✅
# Success: Renamed 'libpng-config' to '__~libpng-config' ✅
# Success: Renamed 'mpicc' to '__~mpicc' ✅
# Success: Renamed 'x86_64-linux-gnu-pkg-config' to '__~x86_64-linux-gnu-pkg-config' ✅
# Success: Renamed 'ifnames' to '__~ifnames' ✅
# Success: Renamed 'shmemCC' to '__~shmemCC' ✅
# Success: Renamed 'vipe' to '__~vipe' ✅
# Success: Renamed 'gio-querymodules' to '__~gio-querymodules' ✅
# Success: Renamed 'ts' to '__~ts' ✅
# Success: Renamed 'jaotc' to '__~jaotc' ✅
# Success: Renamed 'resolvectl' to '__~resolvectl' ✅
# Success: Renamed 'gpic' to '__~gpic' ✅
# Success: Renamed 'acyclic' to '__~acyclic' ✅
# Success: Renamed 'routel' to '__~routel' ✅
# Success: Renamed 'pic' to '__~pic' ✅
# Success: Renamed 'colcrt' to '__~colcrt' ✅
# Success: Renamed 'col' to '__~col' ✅
# Success: Renamed 'fuser' to '__~fuser' ✅
# Success: Renamed 'systemd-analyze' to '__~systemd-analyze' ✅
# Success: Renamed 'dh_autotools-dev_restoreconfig' to '__~dh_autotools-dev_restoreconfig' ✅
# Success: Renamed 'geos-config' to '__~geos-config' ✅
# Success: Renamed 'systemd-notify' to '__~systemd-notify' ✅
# Success: Renamed 'unrar-nonfree' to '__~unrar-nonfree' ✅
# Success: Renamed 'systemd-machine-id-setup' to '__~systemd-machine-id-setup' ✅
# Success: Renamed 'pstree' to '__~pstree' ✅
# Success: Renamed 'lsof' to '__~lsof' ✅
# Success: Renamed 'gdal-config' to '__~gdal-config' ✅
# Success: Renamed 'wget' to '__~wget' ✅
# Success: Renamed 'open' to '__~open' ✅
# Success: Renamed 'gio' to '__~gio' ✅
# Success: Renamed 'jstatd' to '__~jstatd' ✅
# Success: Renamed 'kmod' to '__~kmod' ✅
# Success: Renamed 'ffplay' to '__~ffplay' ✅
# Success: Renamed 'mispipe' to '__~mispipe' ✅
# Success: Renamed 'vim.basic' to '__~vim.basic' ✅
# Success: Renamed 'orte-info' to '__~orte-info' ✅
# Success: Renamed 'clinfo' to '__~clinfo' ✅
# Success: Renamed 'jcmd' to '__~jcmd' ✅
# Success: Renamed 'mpexpand' to '__~mpexpand' ✅
# Success: Renamed 'mpic++.openmpi' to '__~mpic++.openmpi' ✅
# Success: Renamed 'funzip' to '__~funzip' ✅
# Success: Renamed 'cautious-launcher' to '__~cautious-launcher' ✅
# Success: Renamed 'bootctl' to '__~bootctl' ✅
# Success: Renamed 'jmod' to '__~jmod' ✅
# Success: Renamed 'mpijavac' to '__~mpijavac' ✅
# Success: Renamed 'edit' to '__~edit' ✅
# Success: Renamed 'osage' to '__~osage' ✅
# Success: Renamed 'mpicc.openmpi' to '__~mpicc.openmpi' ✅
# Success: Renamed 'dbus-cleanup-sockets' to '__~dbus-cleanup-sockets' ✅
# Success: Renamed 'slogin' to '__~slogin' ✅
# Success: Renamed 'ifne' to '__~ifne' ✅
# Success: Renamed 'systemd-inhibit' to '__~systemd-inhibit' ✅
# Success: Renamed 'pygettext3' to '__~pygettext3' ✅
# Success: Renamed 'apt-add-repository' to '__~apt-add-repository' ✅
# Success: Renamed 'gxl2gv' to '__~gxl2gv' ✅
# Success: Renamed 'shmemfort' to '__~shmemfort' ✅
# Success: Renamed 'xml2-config' to '__~xml2-config' ✅
# Success: Renamed 'shmemcc' to '__~shmemcc' ✅
# Success: Renamed 'run-mailcap' to '__~run-mailcap' ✅
# Success: Renamed 'prune' to '__~prune' ✅
# Success: Renamed 'update-mime-database' to '__~update-mime-database' ✅
# Success: Renamed 'm4' to '__~m4' ✅
# Success: Renamed 'hexdump' to '__~hexdump' ✅
# Success: Renamed 'git-upload-pack' to '__~git-upload-pack' ✅
# Success: Renamed 'jimage' to '__~jimage' ✅
# Success: Renamed 'man-recode' to '__~man-recode' ✅
# Success: Renamed 'rmic' to '__~rmic' ✅
# Success: Renamed 'shmemcxx' to '__~shmemcxx' ✅
# Success: Renamed 'sudo' to '__~sudo' ✅
# Success: Renamed 'pprof-symbolize' to '__~pprof-symbolize' ✅
# Success: Renamed 'mpirun' to '__~mpirun' ✅
# Success: Renamed 'vim' to '__~vim' ✅
# Success: Renamed 'man.REAL' to '__~man.REAL' ✅
# Success: Renamed 'f77' to '__~f77' ✅
# Success: Renamed 'bjam' to '__~bjam' ✅
# Success: Renamed 'gencfu' to '__~gencfu' ✅
# Success: Renamed 'fio-dedupe' to '__~fio-dedupe' ✅
# Success: Renamed 'zipinfo' to '__~zipinfo' ✅
# Success: Renamed 'rlogin' to '__~rlogin' ✅
# Success: Renamed 'shmemc++' to '__~shmemc++' ✅
# Success: Renamed 'wish8.6' to '__~wish8.6' ✅
# Success: Renamed 'systemd-escape' to '__~systemd-escape' ✅
# Success: Renamed 'rtstat' to '__~rtstat' ✅
# Success: Renamed 'isutf8' to '__~isutf8' ✅
# Success: Renamed 'nop' to '__~nop' ✅
# Success: Renamed 'preconv' to '__~preconv' ✅
# Success: Renamed 'systemd-path' to '__~systemd-path' ✅
# Success: Renamed 'column' to '__~column' ✅
# Success: Renamed 'asan_symbolize-14' to '__~asan_symbolize-14' ✅
# Success: Renamed 'hd' to '__~hd' ✅
# Success: Renamed 'mpiexec.openmpi' to '__~mpiexec.openmpi' ✅
# Success: Renamed 'opalc++' to '__~opalc++' ✅
# Success: Renamed 'systemd-stdio-bridge' to '__~systemd-stdio-bridge' ✅
# Success: Renamed 'nroff' to '__~nroff' ✅
# Success: Renamed 'mysql_config' to '__~mysql_config' ✅
# Success: Renamed 'zrun' to '__~zrun' ✅
# Success: Renamed 'jdb' to '__~jdb' ✅
# Success: Renamed 'jdeprscan' to '__~jdeprscan' ✅
# Success: Renamed 'lesskey' to '__~lesskey' ✅
# Success: Renamed 'bcp' to '__~bcp' ✅
# Success: Renamed 'xdg-desktop-icon' to '__~xdg-desktop-icon' ✅
# Success: Renamed 'page' to '__~page' ✅
# Success: Renamed 'rsync-ssl' to '__~rsync-ssl' ✅
# Success: Renamed 'py3versions' to '__~py3versions' ✅
# Success: Renamed 'dot' to '__~dot' ✅
# Success: Renamed 'systemd-mount' to '__~systemd-mount' ✅
# Success: Renamed 'jrunscript' to '__~jrunscript' ✅
# Success: Renamed 'grog' to '__~grog' ✅
# Success: Renamed 'xdg-icon-resource' to '__~xdg-icon-resource' ✅
# Success: Renamed 'catman' to '__~catman' ✅
# Success: Renamed 'lckdo' to '__~lckdo' ✅
# Success: Renamed 'ffprobe' to '__~ffprobe' ✅
# Success: Renamed 'jstack' to '__~jstack' ✅
# Success: Renamed 'dh_autotools-dev_updateconfig' to '__~dh_autotools-dev_updateconfig' ✅
# Success: Renamed 'bcomps' to '__~bcomps' ✅
# Success: Renamed 'less' to '__~less' ✅
# Success: Renamed 'lesspipe' to '__~lesspipe' ✅
# Success: Renamed 'clang' to '__~clang' ✅
# Success: Renamed 'python3.10-config' to '__~python3.10-config' ✅
# Success: Renamed 'systemd-detect-virt' to '__~systemd-detect-virt' ✅
# Success: Renamed 'h5c++' to '__~h5c++' ✅
# Success: Renamed 'unrar' to '__~unrar' ✅
# Success: Renamed 'clang++-14' to '__~clang++-14' ✅
# Success: Renamed 'dbus-update-activation-environment' to '__~dbus-update-activation-environment' ✅
# Success: Renamed 'ompi-clean' to '__~ompi-clean' ✅
# Success: Renamed 'orted' to '__~orted' ✅
# Success: Renamed 'autom4te' to '__~autom4te' ✅
# Success: Renamed 'clang++' to '__~clang++' ✅
# Success: Renamed 'neato' to '__~neato' ✅
# Success: Renamed 'rename' to '__~rename' ✅
# Success: Renamed 'autoheader' to '__~autoheader' ✅
# Success: Renamed 'ssh-keyscan' to '__~ssh-keyscan' ✅
# Success: Renamed 'mandb' to '__~mandb' ✅
# Success: Renamed 'fc-validate' to '__~fc-validate' ✅
# Success: Renamed 'jarsigner' to '__~jarsigner' ✅
# Success: Renamed 'editor' to '__~editor' ✅
# Success: Renamed 'gml2gv' to '__~gml2gv' ✅
# Success: Renamed 'pkg-config' to '__~pkg-config' ✅
# Success: Renamed 'makeconv' to '__~makeconv' ✅
# Success: Renamed 'opencv_annotation' to '__~opencv_annotation' ✅
# Success: Renamed 'x86_64-linux-gnu-gfortran-11' to '__~x86_64-linux-gnu-gfortran-11' ✅
# Success: Renamed 'clang-cpp-14' to '__~clang-cpp-14' ✅
# Success: Renamed 'ncursesw6-config' to '__~ncursesw6-config' ✅
# Success: Renamed 'pdb3.10' to '__~pdb3.10' ✅
# Success: Renamed 'lexgrog' to '__~lexgrog' ✅
# Success: Renamed 'prename' to '__~prename' ✅
# Success: Renamed 'pcre-config' to '__~pcre-config' ✅
# Success: Renamed 'lefty' to '__~lefty' ✅
# Success: Renamed 'circo' to '__~circo' ✅
# Success: Renamed 'sudoedit' to '__~sudoedit' ✅
# Success: Renamed 'pkgdata' to '__~pkgdata' ✅
# Success: Renamed 'geqn' to '__~geqn' ✅
# Success: Renamed 'sfdp' to '__~sfdp' ✅
# Success: Renamed 'loginctl' to '__~loginctl' ✅
# Success: Renamed 'gv2gxl' to '__~gv2gxl' ✅
# Success: Renamed 'uconv' to '__~uconv' ✅
# Success: Renamed 'fio-btrace2fio' to '__~fio-btrace2fio' ✅
# Success: Renamed 'dbus-uuidgen' to '__~dbus-uuidgen' ✅
# Success: Renamed 'jstat' to '__~jstat' ✅
# Success: Renamed 'neqn' to '__~neqn' ✅
# Success: Renamed 'mpic++' to '__~mpic++' ✅
# Success: Renamed 'sponge' to '__~sponge' ✅
# Success: Renamed 'lessecho' to '__~lessecho' ✅
# Success: Renamed 'x86_64-linux-gnu-gfortran' to '__~x86_64-linux-gnu-gfortran' ✅
# Success: Renamed 'fc-cat' to '__~fc-cat' ✅
# Success: Renamed 'fusermount' to '__~fusermount' ✅
# Success: Renamed 'opalcc' to '__~opalcc' ✅
# Success: Renamed 'apt-extracttemplates' to '__~apt-extracttemplates' ✅
# Success: Renamed 'genbrk' to '__~genbrk' ✅
# Success: Renamed 'apt-ftparchive' to '__~apt-ftparchive' ✅
# Success: Renamed 'systemd-ask-password' to '__~systemd-ask-password' ✅
# Success: Renamed 'pg_config' to '__~pg_config' ✅
# Success: Renamed 'cluster' to '__~cluster' ✅
# Success: Renamed 'derb' to '__~derb' ✅
# Success: Renamed 'cmake' to '__~cmake' ✅
# Success: Renamed 'nstat' to '__~nstat' ✅
# Success: Renamed 'icuexportdata' to '__~icuexportdata' ✅
# Success: Renamed 'mpif90.openmpi' to '__~mpif90.openmpi' ✅
# Success: Renamed 'h5fc' to '__~h5fc' ✅
# Success: Renamed 'dijkstra' to '__~dijkstra' ✅
# Success: Renamed 'jdeps' to '__~jdeps' ✅
# Success: Renamed 'gfortran-11' to '__~gfortran-11' ✅
# Success: Renamed 'write' to '__~write' ✅
# Success: Renamed 'cvtsudoers' to '__~cvtsudoers' ✅
# Success: Renamed 'patchwork' to '__~patchwork' ✅
# Success: Renamed 'dotty' to '__~dotty' ✅
# Success: Renamed 'java' to '__~java' ✅
# Success: Renamed 'oshrun' to '__~oshrun' ✅
# Success: Renamed 'twopi' to '__~twopi' ✅
# Success: Renamed 'rsync' to '__~rsync' ✅
# Success: Renamed 'python3-config' to '__~python3-config' ✅
# Success: Renamed 'rmiregistry' to '__~rmiregistry' ✅
# Success: Renamed 'sccmap' to '__~sccmap' ✅
# Success: Renamed 'wish' to '__~wish' ✅
# Success: Renamed 'opencv_model_diagnostics' to '__~opencv_model_diagnostics' ✅
# Success: Renamed 'jlink' to '__~jlink' ✅
# Success: Renamed 'genrb' to '__~genrb' ✅
# Success: Renamed 'zip' to '__~zip' ✅
# Success: Renamed 'ssh-copy-id' to '__~ssh-copy-id' ✅
# Success: Renamed 'edgepaint' to '__~edgepaint' ✅
# Success: Renamed 'qt-faststart' to '__~qt-faststart' ✅
# Success: Renamed 'profile2mat' to '__~profile2mat' ✅
# Success: Renamed 'rview' to '__~rview' ✅
# Success: Renamed 'fc-query' to '__~fc-query' ✅
# Success: Renamed 'ctstat' to '__~ctstat' ✅
# Success: Renamed 'orte-server' to '__~orte-server' ✅
# Success: Renamed 'whatis' to '__~whatis' ✅
# Success: Renamed 'gtk-update-icon-cache' to '__~gtk-update-icon-cache' ✅
# Success: Renamed 'unflatten' to '__~unflatten' ✅
# Success: Renamed 'soelim' to '__~soelim' ✅
# Success: Renamed 'zipcloak' to '__~zipcloak' ✅
# Success: Renamed 'paperconf' to '__~paperconf' ✅
# Success: Renamed 'x86_64-linux-gnu-python3-config' to '__~x86_64-linux-gnu-python3-config' ✅
# Success: Renamed 'lsb_release' to '__~lsb_release' ✅
# Success: Renamed 'icuinfo' to '__~icuinfo' ✅
# Success: Renamed 'opencv_interactive-calibration' to '__~opencv_interactive-calibration' ✅
# Success: Renamed 'autoconf' to '__~autoconf' ✅
# Success: Renamed 'shmemrun' to '__~shmemrun' ✅
# Success: Renamed 'systemd-tmpfiles' to '__~systemd-tmpfiles' ✅
# Success: Renamed 'py3clean' to '__~py3clean' ✅
# Success: Renamed 'aggregate_profile' to '__~aggregate_profile' ✅
# Success: Renamed 'peekfd' to '__~peekfd' ✅
# Success: Renamed 'pack200' to '__~pack200' ✅
# Success: Renamed 'gfortran' to '__~gfortran' ✅
# Success: Renamed 'krb5-config.mit' to '__~krb5-config.mit' ✅
# Success: Renamed 'rdma' to '__~rdma' ✅
# Success: Renamed 'apt-sortpkgs' to '__~apt-sortpkgs' ✅
# Success: Renamed 'keytool' to '__~keytool' ✅
# Success: Renamed 'gvpack' to '__~gvpack' ✅
# Success: Renamed 'pslog' to '__~pslog' ✅
# Success: Renamed 'ssh-add' to '__~ssh-add' ✅
# Success: Renamed 'oshfort' to '__~oshfort' ✅
# Success: Renamed 'mpif90' to '__~mpif90' ✅
# Success: Renamed 'autoupdate' to '__~autoupdate' ✅
# Success: Renamed 'mpiexec' to '__~mpiexec' ✅
# Success: Renamed 'gvmap.sh' to '__~gvmap.sh' ✅
# Success: Renamed 'mingle' to '__~mingle' ✅
# Success: Renamed 'fio' to '__~fio' ✅
# Success: Renamed 'add-apt-repository' to '__~add-apt-repository' ✅
# Success: Renamed 'rcp' to '__~rcp' ✅
# Success: Renamed 'unpack200' to '__~unpack200' ✅
# Success: Renamed 'systemd-delta' to '__~systemd-delta' ✅
# Success: Renamed 'autoscan' to '__~autoscan' ✅
# Success: Renamed 'prtstat' to '__~prtstat' ✅
# Success: Renamed 'mpicxx' to '__~mpicxx' ✅
# Success: Renamed 'lcf' to '__~lcf' ✅
# Success: Renamed 'sftp' to '__~sftp' ✅
# Success: Renamed 'fc-conflist' to '__~fc-conflist' ✅
# Success: Renamed 'automake-1.16' to '__~automake-1.16' ✅
# Success: Renamed 'systemd-socket-activate' to '__~systemd-socket-activate' ✅
# Success: Renamed 'pdb3' to '__~pdb3' ✅
# Success: Renamed 'systemd-cgls' to '__~systemd-cgls' ✅
# Success: Renamed 'fio-genzipf' to '__~fio-genzipf' ✅
# Success: Renamed 'ex' to '__~ex' ✅
# Success: Renamed 'py3compile' to '__~py3compile' ✅
# Success: Renamed 'orte-clean' to '__~orte-clean' ✅
# Success: Renamed 'jexec' to '__~jexec' ✅
# Success: Renamed 'oshc++' to '__~oshc++' ✅
# Success: Renamed 'ssh-keygen' to '__~ssh-keygen' ✅
# Success: Renamed 'pygettext3.10' to '__~pygettext3.10' ✅
# Success: Renamed 'gvpr' to '__~gvpr' ✅
# Success: Renamed 'gdbus' to '__~gdbus' ✅
# Success: Renamed 'pkgconf' to '__~pkgconf' ✅
# Success: Renamed 'ccomps' to '__~ccomps' ✅
# Success: Renamed 'file-rename' to '__~file-rename' ✅
# Success: Renamed 'git-lfs' to '__~git-lfs' ✅
# Success: Renamed 'f95' to '__~f95' ✅
# Success: Renamed 'javac' to '__~javac' ✅
# Success: Renamed 'unzipsfx' to '__~unzipsfx' ✅
# Success: Renamed 'fdp' to '__~fdp' ✅
# Success: Renamed 'tcldocstrip' to '__~tcldocstrip' ✅
# Success: Renamed 'fc-cache' to '__~fc-cache' ✅
# Success: Renamed 'p7zip' to '__~p7zip' ✅
# Success: Renamed 'xauth' to '__~xauth' ✅
# Success: Renamed 'ulockmgr_server' to '__~ulockmgr_server' ✅
# Success: Renamed 'google-pprof' to '__~google-pprof' ✅
# Success: Renamed 'colrm' to '__~colrm' ✅
# Success: Renamed 'fc-pattern' to '__~fc-pattern' ✅
# Success: Renamed 'vimdiff' to '__~vimdiff' ✅
# Success: Renamed 'killall' to '__~killall' ✅
# Success: Renamed '7z' to '__~7z' ✅
# Success: Renamed 'xdg-desktop-menu' to '__~xdg-desktop-menu' ✅
# Success: Renamed 'grops' to '__~grops' ✅
# Success: Renamed 'javadoc' to '__~javadoc' ✅
# Success: Renamed 'gvcolor' to '__~gvcolor' ✅
# Success: Renamed 'ul' to '__~ul' ✅
# Success: Renamed 'dot_builtins' to '__~dot_builtins' ✅
# Success: Renamed 'nns' to '__~nns' ✅
# Success: Renamed 'manpath' to '__~manpath' ✅
# Success: Renamed 'opencv_version' to '__~opencv_version' ✅
# Success: Renamed 'gc' to '__~gc' ✅
# Success: Renamed 'errno' to '__~errno' ✅
# Success: Renamed 'gencnval' to '__~gencnval' ✅
# Success: Renamed 'git-shell' to '__~git-shell' ✅
# Success: Renamed 'lneato' to '__~lneato' ✅
# Success: Renamed 'pkttyagent' to '__~pkttyagent' ✅
# Success: Renamed 'nnslog' to '__~nnslog' ✅
# Success: Renamed 'rsh' to '__~rsh' ✅
# Success: Renamed 'python3.11-config' to '__~python3.11-config' ✅
# Success: Renamed 'automake' to '__~automake' ✅
# Success: Renamed 'dbus-monitor' to '__~dbus-monitor' ✅
# Success: Renamed 'pydoc3.10' to '__~pydoc3.10' ✅
# Success: Renamed 'systemd-umount' to '__~systemd-umount' ✅
# Success: Renamed 'vimtutor' to '__~vimtutor' ✅
# Success: Renamed 'jjs' to '__~jjs' ✅
# Success: Renamed 'jfr' to '__~jfr' ✅
# Success: Renamed 'h5cc' to '__~h5cc' ✅
# Success: Renamed 'pee' to '__~pee' ✅
# Success: Renamed 'ucfq' to '__~ucfq' ✅
# Success: Renamed 'pkexec' to '__~pkexec' ✅
# Success: Renamed 'systemd-sysusers' to '__~systemd-sysusers' ✅
# Success: Renamed 'ompi-server' to '__~ompi-server' ✅
# Success: Renamed 'timedatectl' to '__~timedatectl' ✅
# Success: Renamed 'libpng16-config' to '__~libpng16-config' ✅
# Success: Renamed 'asan_symbolize' to '__~asan_symbolize' ✅
# Success: Renamed 'networkctl' to '__~networkctl' ✅
# Success: Renamed 'nc-config' to '__~nc-config' ✅
# Success: Renamed 'pydoc3.11' to '__~pydoc3.11' ✅
# Success: Renamed 'mpicxx.openmpi' to '__~mpicxx.openmpi' ✅
# Success: Renamed 'dot2gxl' to '__~dot2gxl' ✅
# Success: Renamed 'systemd' to '__~systemd' ✅
# Success: Renamed 'gendict' to '__~gendict' ✅
# Success: Renamed 'opal_wrapper' to '__~opal_wrapper' ✅
# Success: Renamed 'jps' to '__~jps' ✅
# Success: Renamed 'curl' to '__~curl' ✅
# Success: Renamed 'mpifort.openmpi' to '__~mpifort.openmpi' ✅
# Success: Renamed 'x86_64-linux-gnu-python3.10-config' to '__~x86_64-linux-gnu-python3.10-config' ✅
# Success: Renamed 'opencv_waldboost_detector' to '__~opencv_waldboost_detector' ✅
# Success: Renamed 'b2' to '__~b2' ✅
# Success: Renamed 'jshell' to '__~jshell' ✅
# Success: Renamed 'fc-match' to '__~fc-match' ✅
# Success: Renamed 'rmid' to '__~rmid' ✅
# Success: Renamed 'systemd-id128' to '__~systemd-id128' ✅
# Success: Renamed 'systemd-sysext' to '__~systemd-sysext' ✅
# Success: Renamed 'ncurses6-config' to '__~ncurses6-config' ✅
# Success: Renamed '7zr' to '__~7zr' ✅
# Success: Renamed 'protoc' to '__~protoc' ✅
# Success: Renamed 'mpif77.openmpi' to '__~mpif77.openmpi' ✅
# Success: Renamed 'mpif77' to '__~mpif77' ✅
# Success: Renamed 'pl2pm' to '__~pl2pm' ✅
# Success: Renamed 'patch' to '__~patch' ✅
# Success: Renamed 'dpkg-checkbuilddeps' to '__~dpkg-checkbuilddeps' ✅
# Success: Renamed 'x86_64-linux-gnu-cpp' to '__~x86_64-linux-gnu-cpp' ✅
# Success: Renamed 'c99' to '__~c99' ✅
# Success: Renamed 'perlivp' to '__~perlivp' ✅
# Success: Renamed 'g++-11' to '__~g++-11' ✅
# Success: Renamed 'gcc-ranlib-11' to '__~gcc-ranlib-11' ✅
# Success: Renamed 'rpcgen' to '__~rpcgen' ✅
# Success: Renamed 'cpan' to '__~cpan' ✅
# Success: Renamed 'dpkg-shlibdeps' to '__~dpkg-shlibdeps' ✅
# Success: Renamed 'x86_64-linux-gnu-objdump' to '__~x86_64-linux-gnu-objdump' ✅
# Success: Renamed 'dpkg-vendor' to '__~dpkg-vendor' ✅
# Success: Renamed 'pod2html' to '__~pod2html' ✅
# Success: Renamed 'unlzma' to '__~unlzma' ✅
# Success: Renamed 'bzexe' to '__~bzexe' ✅
# Success: Renamed 'xzmore' to '__~xzmore' ✅
# Success: Renamed 'gcc-ar-11' to '__~gcc-ar-11' ✅
# Success: Renamed 'h2ph' to '__~h2ph' ✅
# Success: Renamed 'ptargrep' to '__~ptargrep' ✅
# Success: Renamed 'x86_64-linux-gnu-gcc-nm' to '__~x86_64-linux-gnu-gcc-nm' ✅
# Success: Renamed 'ld' to '__~ld' ✅
# Success: Renamed 'gcc-11' to '__~gcc-11' ✅
# Success: Renamed 'encguess' to '__~encguess' ✅
# Success: Renamed 'x86_64-linux-gnu-objcopy' to '__~x86_64-linux-gnu-objcopy' ✅
# Success: Renamed 'x86_64-linux-gnu-gcc-ranlib-11' to '__~x86_64-linux-gnu-gcc-ranlib-11' ✅
# Success: Renamed 'gcov-11' to '__~gcov-11' ✅
# Success: Renamed 'pod2text' to '__~pod2text' ✅
# Success: Renamed 'cpp' to '__~cpp' ✅
# Success: Renamed 'ld.bfd' to '__~ld.bfd' ✅
# Success: Renamed 'x86_64-linux-gnu-gcov-dump-11' to '__~x86_64-linux-gnu-gcov-dump-11' ✅
# Success: Renamed 'x86_64-linux-gnu-gold' to '__~x86_64-linux-gnu-gold' ✅
# Success: Renamed 'x86_64-linux-gnu-gcov-tool-11' to '__~x86_64-linux-gnu-gcov-tool-11' ✅
# Success: Renamed 'lzfgrep' to '__~lzfgrep' ✅
# Success: Renamed 'perl5.34-x86_64-linux-gnu' to '__~perl5.34-x86_64-linux-gnu' ✅
# Success: Renamed 'lzmore' to '__~lzmore' ✅
# Success: Renamed 'lzless' to '__~lzless' ✅
# Success: Renamed 'x86_64-linux-gnu-ranlib' to '__~x86_64-linux-gnu-ranlib' ✅
# Success: Renamed 'dpkg-distaddfile' to '__~dpkg-distaddfile' ✅
# Success: Renamed 'size' to '__~size' ✅
# Success: Renamed 'make-first-existing-target' to '__~make-first-existing-target' ✅
# Success: Renamed 'x86_64-linux-gnu-g++-11' to '__~x86_64-linux-gnu-g++-11' ✅
# Success: Renamed 'dpkg-architecture' to '__~dpkg-architecture' ✅
# Success: Renamed 'unxz' to '__~unxz' ✅
# Success: Renamed 'libnetcfg' to '__~libnetcfg' ✅
# Success: Renamed 'dpkg-genchanges' to '__~dpkg-genchanges' ✅
# Success: Renamed 'gcov' to '__~gcov' ✅
# Success: Renamed 'dpkg-gencontrol' to '__~dpkg-gencontrol' ✅
# Success: Renamed 'streamzip' to '__~streamzip' ✅
# Success: Renamed 'x86_64-linux-gnu-cpp-11' to '__~x86_64-linux-gnu-cpp-11' ✅
# Success: Renamed 'gold' to '__~gold' ✅
# Success: Renamed 'c++filt' to '__~c++filt' ✅
# Success: Renamed 'objcopy' to '__~objcopy' ✅
# Success: Renamed 'strings' to '__~strings' ✅
# Success: Renamed 'x86_64-linux-gnu-elfedit' to '__~x86_64-linux-gnu-elfedit' ✅
# Success: Renamed 'bzmore' to '__~bzmore' ✅
# Success: Renamed 'ld.gold' to '__~ld.gold' ✅
# Success: Renamed 'bzegrep' to '__~bzegrep' ✅
# Success: Renamed 'xzegrep' to '__~xzegrep' ✅
# Success: Renamed 'objdump' to '__~objdump' ✅
# Success: Renamed 'bzip2' to '__~bzip2' ✅
# Success: Renamed 'g++' to '__~g++' ✅
# Success: Renamed 'x86_64-linux-gnu-gcc-nm-11' to '__~x86_64-linux-gnu-gcc-nm-11' ✅
# Success: Renamed 'ar' to '__~ar' ✅
# Success: Renamed 'h2xs' to '__~h2xs' ✅
# Success: Renamed 'pod2usage' to '__~pod2usage' ✅
# Success: Renamed 'dpkg-parsechangelog' to '__~dpkg-parsechangelog' ✅
# Success: Renamed 'bzcat' to '__~bzcat' ✅
# Success: Renamed 'xzcmp' to '__~xzcmp' ✅
# Success: Renamed 'gcc-nm' to '__~gcc-nm' ✅
# Success: Renamed 'dpkg-source' to '__~dpkg-source' ✅
# Success: Renamed 'x86_64-linux-gnu-ld.gold' to '__~x86_64-linux-gnu-ld.gold' ✅
# Success: Renamed 'perldoc' to '__~perldoc' ✅
# Success: Renamed 'x86_64-linux-gnu-gcov-11' to '__~x86_64-linux-gnu-gcov-11' ✅
# Success: Renamed 'enc2xs' to '__~enc2xs' ✅
# Success: Renamed 'x86_64-linux-gnu-gcc-ar-11' to '__~x86_64-linux-gnu-gcc-ar-11' ✅
# Success: Renamed 'make' to '__~make' ✅
# Success: Renamed 'json_pp' to '__~json_pp' ✅
# Success: Renamed 'xzgrep' to '__~xzgrep' ✅
# Success: Renamed 'lzegrep' to '__~lzegrep' ✅
# Success: Renamed 'addr2line' to '__~addr2line' ✅
# Success: Renamed 'lzcat' to '__~lzcat' ✅
# Success: Renamed 'xsubpp' to '__~xsubpp' ✅
# Success: Renamed 'piconv' to '__~piconv' ✅
# Success: Renamed 'instmodsh' to '__~instmodsh' ✅
# Success: Renamed 'gcov-dump' to '__~gcov-dump' ✅
# Success: Renamed 'x86_64-linux-gnu-gcc-ar' to '__~x86_64-linux-gnu-gcc-ar' ✅
# Success: Renamed 'prove' to '__~prove' ✅
# Success: Renamed 'bzdiff' to '__~bzdiff' ✅
# Success: Renamed 'splain' to '__~splain' ✅
# Success: Renamed 'c89' to '__~c89' ✅
# Success: Renamed 'c++' to '__~c++' ✅
# Success: Renamed 'x86_64-linux-gnu-as' to '__~x86_64-linux-gnu-as' ✅
# Success: Renamed 'perlbug' to '__~perlbug' ✅
# Success: Renamed 'dpkg-mergechangelogs' to '__~dpkg-mergechangelogs' ✅
# Success: Renamed 'gcc-ar' to '__~gcc-ar' ✅
# Success: Renamed 'c99-gcc' to '__~c99-gcc' ✅
# Success: Renamed 'gcc-ranlib' to '__~gcc-ranlib' ✅
# Success: Renamed 'x86_64-linux-gnu-ld.bfd' to '__~x86_64-linux-gnu-ld.bfd' ✅
# Success: Renamed 'x86_64-linux-gnu-readelf' to '__~x86_64-linux-gnu-readelf' ✅
# Success: Renamed 'bzcmp' to '__~bzcmp' ✅
# Success: Renamed 'cpp-11' to '__~cpp-11' ✅
# Success: Renamed 'zipdetails' to '__~zipdetails' ✅
# Success: Renamed 'bzip2recover' to '__~bzip2recover' ✅
# Success: Renamed 'xz' to '__~xz' ✅
# Success: Renamed 'dpkg-buildpackage' to '__~dpkg-buildpackage' ✅
# Success: Renamed 'x86_64-linux-gnu-gcov' to '__~x86_64-linux-gnu-gcov' ✅
# Success: Renamed 'lzdiff' to '__~lzdiff' ✅
# Success: Renamed 'gcc-nm-11' to '__~gcc-nm-11' ✅
# Success: Renamed 'cpan5.34-x86_64-linux-gnu' to '__~cpan5.34-x86_64-linux-gnu' ✅
# Success: Renamed 'x86_64-linux-gnu-c++filt' to '__~x86_64-linux-gnu-c++filt' ✅
# Success: Renamed 'gcov-tool-11' to '__~gcov-tool-11' ✅
# Success: Renamed 'shasum' to '__~shasum' ✅
# Success: Renamed 'x86_64-linux-gnu-lto-dump-11' to '__~x86_64-linux-gnu-lto-dump-11' ✅
# Success: Renamed 'x86_64-linux-gnu-nm' to '__~x86_64-linux-gnu-nm' ✅
# Success: Renamed 'as' to '__~as' ✅
# Success: Renamed 'lzmainfo' to '__~lzmainfo' ✅
# Success: Renamed 'x86_64-linux-gnu-ld' to '__~x86_64-linux-gnu-ld' ✅
# Success: Renamed 'x86_64-linux-gnu-addr2line' to '__~x86_64-linux-gnu-addr2line' ✅
# Success: Renamed 'pod2man' to '__~pod2man' ✅
# Success: Renamed 'x86_64-linux-gnu-size' to '__~x86_64-linux-gnu-size' ✅
# Success: Renamed 'gprof' to '__~gprof' ✅
# Success: Renamed 'lzcmp' to '__~lzcmp' ✅
# Success: Renamed 'c89-gcc' to '__~c89-gcc' ✅
# Success: Renamed 'x86_64-linux-gnu-gcc-11' to '__~x86_64-linux-gnu-gcc-11' ✅
# Success: Renamed 'dpkg-gensymbols' to '__~dpkg-gensymbols' ✅
# Success: Renamed 'dpkg-genbuildinfo' to '__~dpkg-genbuildinfo' ✅
# Success: Renamed 'ptardiff' to '__~ptardiff' ✅
# Success: Renamed 'nm' to '__~nm' ✅
# Success: Renamed 'gmake' to '__~gmake' ✅
# Success: Renamed 'gcc' to '__~gcc' ✅
# Success: Renamed 'xzless' to '__~xzless' ✅
# Success: Renamed 'corelist' to '__~corelist' ✅
# Success: Renamed 'dpkg-scanpackages' to '__~dpkg-scanpackages' ✅
# Success: Renamed 'x86_64-linux-gnu-gprof' to '__~x86_64-linux-gnu-gprof' ✅
# Success: Renamed 'lzgrep' to '__~lzgrep' ✅
# Success: Renamed 'bunzip2' to '__~bunzip2' ✅
# Success: Renamed 'ranlib' to '__~ranlib' ✅
# Success: Renamed 'podchecker' to '__~podchecker' ✅
# Success: Renamed 'x86_64-linux-gnu-gcc-ranlib' to '__~x86_64-linux-gnu-gcc-ranlib' ✅
# Success: Renamed 'dpkg-buildflags' to '__~dpkg-buildflags' ✅
# Success: Renamed 'x86_64-linux-gnu-strings' to '__~x86_64-linux-gnu-strings' ✅
# Success: Renamed 'x86_64-linux-gnu-gcov-dump' to '__~x86_64-linux-gnu-gcov-dump' ✅
# Success: Renamed 'cc' to '__~cc' ✅
# Success: Renamed 'dwp' to '__~dwp' ✅
# Success: Renamed 'ptar' to '__~ptar' ✅
# Success: Renamed 'x86_64-linux-gnu-dwp' to '__~x86_64-linux-gnu-dwp' ✅
# Success: Renamed 'x86_64-linux-gnu-ar' to '__~x86_64-linux-gnu-ar' ✅
# Success: Renamed 'x86_64-linux-gnu-gcov-tool' to '__~x86_64-linux-gnu-gcov-tool' ✅
# Success: Renamed 'x86_64-linux-gnu-strip' to '__~x86_64-linux-gnu-strip' ✅
# Success: Renamed 'gcov-dump-11' to '__~gcov-dump-11' ✅
# Success: Renamed 'perlthanks' to '__~perlthanks' ✅
# Success: Renamed 'lto-dump-11' to '__~lto-dump-11' ✅
# Success: Renamed 'bzgrep' to '__~bzgrep' ✅
# Success: Renamed 'x86_64-linux-gnu-gcc' to '__~x86_64-linux-gnu-gcc' ✅
# Success: Renamed 'xzcat' to '__~xzcat' ✅
# Success: Renamed 'xzfgrep' to '__~xzfgrep' ✅
# Success: Renamed 'lzma' to '__~lzma' ✅
# Success: Renamed 'elfedit' to '__~elfedit' ✅
# Success: Renamed 'strip' to '__~strip' ✅
# Success: Renamed 'gcov-tool' to '__~gcov-tool' ✅
# Success: Renamed 'readelf' to '__~readelf' ✅
# Success: Renamed 'bzless' to '__~bzless' ✅
# Success: Renamed 'bzfgrep' to '__~bzfgrep' ✅
# Success: Renamed 'dpkg-name' to '__~dpkg-name' ✅
# Success: Renamed 'x86_64-linux-gnu-g++' to '__~x86_64-linux-gnu-g++' ✅
# Success: Renamed 'dpkg-scansources' to '__~dpkg-scansources' ✅
# Success: Renamed 'xzdiff' to '__~xzdiff' ✅
# Success: Renamed 'gpgcompose' to '__~gpgcompose' ✅
# Success: Renamed 'gpg-agent' to '__~gpg-agent' ✅
# Success: Renamed 'gpg2' to '__~gpg2' ✅
# Success: Renamed 'gpgtar' to '__~gpgtar' ✅
# Success: Renamed 'lspgpot' to '__~lspgpot' ✅
# Success: Renamed 'gpgconf' to '__~gpgconf' ✅
# Success: Renamed 'migrate-pubring-from-classic-gpg' to '__~migrate-pubring-from-classic-gpg' ✅
# Success: Renamed 'gpg' to '__~gpg' ✅
# Success: Renamed 'dirmngr-client' to '__~dirmngr-client' ✅
# Success: Renamed 'openssl' to '__~openssl' ✅
# Success: Renamed 'gpgparsemail' to '__~gpgparsemail' ✅
# Success: Renamed 'gpgsm' to '__~gpgsm' ✅
# Success: Renamed 'gpgsplit' to '__~gpgsplit' ✅
# Success: Renamed 'c_rehash' to '__~c_rehash' ✅
# Success: Renamed 'pinentry' to '__~pinentry' ✅
# Success: Renamed 'dirmngr' to '__~dirmngr' ✅
# Success: Renamed 'gpg-zip' to '__~gpg-zip' ✅
# Success: Renamed 'watchgnupg' to '__~watchgnupg' ✅
# Success: Renamed 'pinentry-curses' to '__~pinentry-curses' ✅
# Success: Renamed 'kbxutil' to '__~kbxutil' ✅
# Success: Renamed 'gpg-connect-agent' to '__~gpg-connect-agent' ✅
# Success: Renamed 'gpg-wks-server' to '__~gpg-wks-server' ✅
# Bulk renaming process completed! 🚀
